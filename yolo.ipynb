# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5608.0/8062.4 GB disk)

# %%
# !yolo detect train data=/kaggle/input/fight-dataset/data.yaml epochs=100 imgsz=320 device=0,1
# Out:
# ...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 63.5MB/s]
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
#                                                      CUDA:1 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo val model=/kaggle/working/runs/detect/train/weights/best.pt data=/kaggle/input/fight-dataset/data.yaml
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /kaggle/input/fight-dataset/valid/labels... 15 images, 0 backgroun
# val: WARNING ⚠️ Cache directory /kaggle/input/fight-dataset/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         15         45      0.449      0.311      0.283     0.0898
#                  fight         15         45      0.449      0.311      0.283     0.0898
# Speed: 0.1ms preprocess, 9.2ms inference, 0.0ms loss, 121.6ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val
